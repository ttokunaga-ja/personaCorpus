# %% [markdown]
# # Alpha error-slice sketch
#
# A synthetic label-balanced view for deciding which classes merit manual inspection.

# %%
misses = {'account_access': 3, 'delivery_status': 2, 'plan_change': 2, 'refund_request': 4, 'technical_help': 5}
for label, count in sorted(misses.items(), key=lambda item: (-item[1], item[0]))[:3]:
    print(f'{label}: {count} synthetic misses')
# Out:
# technical_help: 5 synthetic misses
# refund_request: 4 synthetic misses
# account_access: 3 synthetic misses

# %% [markdown]
# ## Next pass
#
# Prioritize technical-help and refund-request ambiguity examples. This notebook contains illustrative counts only, not customer records.
