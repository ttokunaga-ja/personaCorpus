# %% [markdown]
# # Evaluation label check
#
# Verify the offline taxonomy and its expected aggregate size before a future local evaluator run.

# %%
labels = {'account_access': 492, 'delivery_status': 476, 'plan_change': 481, 'refund_request': 462, 'technical_help': 489}
assert sum(labels.values()) == 2400
print(f'{len(labels)} labels; total={sum(labels.values())}; range={min(labels.values())}..{max(labels.values())}')
# Out:
# 5 labels; total=2400; range=462..492

# %% [markdown]
# ## Guardrail
#
# Reject future bundles missing a taxonomy key or changing the total without an explicit dataset revision note.
