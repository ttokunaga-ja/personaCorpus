# %% [markdown]
# # Beta delta review
#
# Compare the recorded offline aggregate metrics: Alpha F1 0.873 and Beta F1 0.846.

# %%
alpha = {'f1': 0.873, 'precision': 0.881, 'recall': 0.865}
beta = {'f1': 0.846, 'precision': 0.852, 'recall': 0.841}
print(f"F1 delta (Alpha - Beta): {alpha['f1'] - beta['f1']:+.3f}")
print(f"Beta recall gap to Alpha: {alpha['recall'] - beta['recall']:+.3f}")
# Out:
# F1 delta (Alpha - Beta): +0.027
# Beta recall gap to Alpha: +0.024

# %% [markdown]
# ## Review note
#
# The larger recall difference is the first diagnostic target; no release decision follows from this scratch calculation.
