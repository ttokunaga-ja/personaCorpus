# %% [markdown]
# # Bootstrap confidence intervalDeterministic, illustrative seed-level macro-F1 interval; not a production estimate.

# %%
replicate_f1=[.865,.870,.873,.876,.881]; mean=sum(replicate_f1)/len(replicate_f1); print(f'Alpha mean={mean:.3f}; illustrative 95% interval=[0.865, 0.881]')
# Out:
# Alpha mean=0.873; illustrative 95% interval=[0.865, 0.881]
