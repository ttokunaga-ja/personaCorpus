# %% [markdown]
# # Synthetic slice referenceFive labels and their fixed evaluation supports in the R184 synthetic export.

# %%
supports={'account_access':492,'delivery_status':476,'plan_change':481,'refund_request':462,'technical_help':489}; print(f'labels={len(supports)} support={sum(supports.values())}; smallest={min(supports,key=supports.get)}')
# Out:
# labels=5 support=2400; smallest=refund_request
