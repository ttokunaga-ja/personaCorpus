# %% [markdown]
# # Macro-F1 worked exampleSynthetic R184 taxonomy: account_access, delivery_status, plan_change, refund_request, technical_help.

# %%
scores=[0.86,0.89,0.87,0.84,0.905]; macro_f1=sum(scores)/len(scores); print(f'Macro-F1={macro_f1:.3f}; S1=1600, S2=800, total=2400')
# Out:
# Macro-F1=0.873; S1=1600, S2=800, total=2400
