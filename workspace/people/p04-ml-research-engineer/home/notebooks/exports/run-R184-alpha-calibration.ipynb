# %% [markdown]
# # Calibration review
#
# Compare confidence bins with their synthetic observed accuracy and identify conservative regions.
#
# **Synthetic evaluation context.** Helix Forge Lab evaluated Model Alpha M-14 on 2026-07-13 in run R184. The recorded macro F1 0.873 is paired with precision 0.881 and recall 0.865. Comparator Model Beta B-07 recorded macro F1 0.846. HF-Eval-S1/S2 v3.2 contains exactly 2,400 synthetic records (S1=1,600; S2=800) across five synthetic intent labels: account_access, delivery_status, plan_change, refund_request, and technical_help. No real subjects or live data are used.
#
# This export is a self-contained offline synthetic analysis notebook.

# %%
bins = [(0.50, 0.61), (0.65, 0.69), (0.80, 0.78), (0.92, 0.89)]
for confidence, accuracy in bins:
    print(f'confidence={confidence:.2f} observed_accuracy={accuracy:.2f} gap={confidence-accuracy:+.2f}')
print('High-confidence bin is mildly overconfident by 0.03.')
# Out:
# confidence=0.50 observed_accuracy=0.61 gap=-0.11
# confidence=0.65 observed_accuracy=0.69 gap=-0.04
# confidence=0.80 observed_accuracy=0.78 gap=+0.02
# confidence=0.92 observed_accuracy=0.89 gap=+0.03
# High-confidence bin is mildly overconfident by 0.03.

# %% [markdown]
# ## Interpretation
#
# Action note: monitor the highest confidence bin and consider a small post-hoc calibration check.
#
# The displayed values remain deterministic synthetic artifacts; no people, production systems, or network services were used.
