# %% [markdown]
# # Error analysis
#
# Classify the synthetic false-negative and false-positive patterns so the next review can target recoverable failures.
#
# **Synthetic evaluation context.** Helix Forge Lab evaluated Model Alpha M-14 on 2026-07-13 in run R184. The recorded macro F1 0.873 is paired with precision 0.881 and recall 0.865. Comparator Model Beta B-07 recorded macro F1 0.846. HF-Eval-S1/S2 v3.2 contains exactly 2,400 synthetic records (S1=1,600; S2=800) across five synthetic intent labels: account_access, delivery_status, plan_change, refund_request, and technical_help. No real subjects or live data are used.
#
# This export is a self-contained offline synthetic analysis notebook.

# %%
error_rows = [('account_access', 18, 9), ('plan_change', 13, 11), ('refund_request', 16, 7), ('delivery_status', 10, 14), ('technical_help', 12, 8)]
for label, fn, fp in error_rows:
    print(f'{label:22} false negatives={fn:2d}  false positives={fp:2d}')
print('Review priority: account_access false negatives (18).')
# Out:
# account_access         false negatives=18  false positives= 9
# plan_change            false negatives=13  false positives=11
# refund_request         false negatives=16  false positives= 7
# delivery_status        false negatives=10  false positives=14
# technical_help         false negatives=12  false positives= 8
# Review priority: account_access false negatives (18).

# %% [markdown]
# ## Interpretation
#
# Action note: prioritize account_access review examples, then audit the refund_request confusion boundary.
#
# The displayed values remain deterministic synthetic artifacts; no people, production systems, or network services were used.
