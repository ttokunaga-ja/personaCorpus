# %% [markdown]
# # R184 error review
#
# **Helix Forge Lab** — Model Alpha M-14, run R184 (2026-07-13). This review uses synthetic aggregate observations only; no production examples or identifiers are included.

# %%
metrics = {'precision': 0.881, 'recall': 0.865, 'f1': 0.873}
review_queue = 96
print(f"Run R184 | precision={metrics['precision']:.3f} | recall={metrics['recall']:.3f} | F1={metrics['f1']:.3f}")
print(f"Aggregate review queue: {review_queue} synthetic cases")
# Out:
# Run R184 | precision=0.881 | recall=0.865 | F1=0.873
# Aggregate review queue: 96 synthetic cases

# %% [markdown]
# ## Aggregate findings
#
# - **delivery_status:** temporal wording accounts for the largest synthetic false-negative cluster.
# - **refund_request:** policy-exception phrasing is the leading synthetic false-positive theme.
# - **account_access:** short recovery requests remain the highest-value calibration slice.
#
# Recommended follow-up: annotate intent boundaries at the aggregate rubric level and compare the next run against the same 96-case synthetic review queue.

# %%
themes = {'delivery_status': 31, 'refund_request': 24, 'account_access': 18, 'other': 23}
themes
# Out:
# {'delivery_status': 31,
#  'refund_request': 24,
#  'account_access': 18,
#  'other': 23}
