# %% [markdown]
# # Alpha / Beta comparison
#
# Helix Forge Lab aggregate benchmark comparison. Model Alpha M-14 (R184, 2026-07-13) is compared with Beta B-07 using synthetic summary metrics.

# %%
alpha = {'precision': 0.881, 'recall': 0.865, 'f1': 0.873}
beta = {'precision': 0.852, 'recall': 0.841, 'f1': 0.846}
{metric: round(alpha[metric] - beta[metric], 3) for metric in alpha}
# Out:
# {'precision': 0.029, 'recall': 0.024, 'f1': 0.027}

# %% [markdown]
# ## Interpretation
#
# Alpha leads Beta by **0.029 precision**, **0.024 recall**, and **0.027 F1**. The difference is material for this aggregate comparison, while the notebook intentionally does not infer significance without per-example data.
#
# Recommended use: retain Alpha as the reference candidate and schedule a rubric-consistent follow-up evaluation.

# %%
print('Model     Precision  Recall  F1')
print('Alpha     0.881      0.865   0.873')
print('Beta      0.852      0.841   0.846')
# Out:
# Model     Precision  Recall  F1
# Alpha     0.881      0.865   0.873
# Beta      0.852      0.841   0.846
