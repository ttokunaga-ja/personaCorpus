# %% [markdown]
# # HF-Eval profile
#
# Helix Forge Lab evaluation profile for **HF-Eval-S1/S2 v3.2**. This is a synthetic aggregate inventory suitable for offline documentation.

# %%
splits = {'S1': 1600, 'S2': 800}
labels = {'account_access': 492, 'delivery_status': 476, 'plan_change': 481, 'refund_request': 462, 'technical_help': 489}
print(f"Total: {sum(splits.values())} | S1: {splits['S1']} | S2: {splits['S2']}")
print(f"Label total: {sum(labels.values())}")
# Out:
# Total: 2400 | S1: 1600 | S2: 800
# Label total: 2400

# %% [markdown]
# ## Composition
#
# | Label | Count |
# | --- | ---: |
# | account_access | 492 |
# | delivery_status | 476 |
# | plan_change | 481 |
# | refund_request | 462 |
# | technical_help | 489 |
#
# The profile is near-balanced across five intent labels. Counts are aggregate only and sum exactly to the 2,400-example evaluation total.

# %%
sum(splits.values()) == sum(labels.values()) == 2400
# Out:
# True
