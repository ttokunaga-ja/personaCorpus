# %% [markdown]
# # Study Alpha quality-control diagnostics
#
# Orchid Cellworks | Study Alpha | 2026-07-13 | cohort A-24 | assay 6.8 ng/mL
#
# Pre-specified QC diagnostics. All data are synthetic and non-clinical.

# %%
import statistics
values = [5.7,6.1,6.3,6.4,6.5,6.6,6.7,6.8,6.8,6.8,6.9,6.9,6.7,6.8,6.9,7.0,6.8,6.7,6.9,6.8,6.6,6.7,6.9,6.8]
median = statistics.median(values)
cv_percent = statistics.pstdev(values) / statistics.mean(values) * 100
print({'n': len(values), 'median_ng_mL': median, 'cv_percent': round(cv_percent, 2)})
# Out:
# {'n': 24, 'median_ng_mL': 6.8, 'cv_percent': 4.34}

# %% [markdown]
# ## Interpretation
# The synthetic cohort meets the predefined reproducibility threshold and supports a documented analytical review.
