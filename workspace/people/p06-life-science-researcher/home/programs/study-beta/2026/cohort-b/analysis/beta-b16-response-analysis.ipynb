# %% [markdown]
# # Study Beta B-16 response analysis
# Orchid Cellworks | 2026-07-13 | Study Beta cohort B-16 wholly synthetic analysis.

# %%
values = [0.98, 1.03, 1.01, 1.07, 1.1, 1.12, 1.15, 1.17, 1.18, 1.19, 1.2, 1.18, 1.22, 1.17, 1.21, 1.19]
baseline = 1.00
mean = sum(values)/len(values)
delta = mean-baseline
print(f"n={len(values)}; mean={mean:.3f}; delta={delta:.3f}")
# Out:
# n=16; mean=1.136; delta=0.136

# %% [markdown]
# ## Acceptance checks
# Duplicate CV must be at or below 10%; formula errors must equal zero.

# %%
target=1.18
print(f"target={target:.2f}; gap={target-mean:.3f}; status=REVIEW")
# Out:
# target=1.18; gap=0.044; status=REVIEW

# %% [markdown]
# ## Interpretation
# Wholly synthetic evidence supports method review only; Study Alpha is contextual and non-equivalent.
