# %% [markdown]
# # A-24 notebook summary
# Orchid Cellworks | Study Alpha | 2026-07-13 | cohort A-24 | assay 6.8 ng/mL

# %%
values = [6.2, 6.5, 6.8, 7.0, 6.9]
median_assay_ng_ml = sorted(values)[len(values)//2]
assert median_assay_ng_ml == 6.8
median_assay_ng_ml
# Out:
# 6.8
