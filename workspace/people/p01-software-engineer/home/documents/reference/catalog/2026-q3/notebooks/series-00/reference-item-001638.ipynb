# %% [markdown]
# # Reference Standard P01-SRC-001638\nProvenance: Aster Loop synthetic Product Engineering.\nSubject: Product Beta R4; Beta R4 contract review.\n

# %%
reference_id = 'REF-26Q3-001638'\nalpha_p95_ms = 184\nbeta_design_budget_ms = 225\nassert alpha_p95_ms < 200\n
