# %% [markdown]
# # Reference Standard P01-SRC-011339\nProvenance: Aster Loop synthetic Product Engineering.\nSubject: Product Alpha R7; ADR-042 asynchronous release gate.\n

# %%
reference_id = 'REF-26Q3-011339'\nalpha_p95_ms = 184\nbeta_design_budget_ms = 225\nassert alpha_p95_ms < 200\n
