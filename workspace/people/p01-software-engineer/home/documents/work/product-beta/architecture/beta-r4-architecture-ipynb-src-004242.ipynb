# %% [markdown]
# # Beta R4 review 004242\n\nAster Loop株式会社 / BETA-R4 / ADR-B4-064 / 2026-08-17 architecture review / 225 ms design p95 budget\n\nSubject: consumer compatibility.\n

# %%
review_id = "ADR-B4-064"\ndesign_budget_ms = 225\nallocated_ms = 158\nassert allocated_ms <= design_budget_ms\n{"review_id": review_id, "component": "ingress adapter", "budget_ms": design_budget_ms}\n
