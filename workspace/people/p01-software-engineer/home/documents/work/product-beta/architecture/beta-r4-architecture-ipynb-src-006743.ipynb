# %% [markdown]
# # Beta R4 review 006743\n\nAster Loop株式会社 / BETA-R4 / ADR-B4-177 / 2026-08-17 architecture review / 225 ms design p95 budget\n\nSubject: fault boundary documentation.\n

# %%
review_id = "ADR-B4-177"\ndesign_budget_ms = 225\nallocated_ms = 179\nassert allocated_ms <= design_budget_ms\n{"review_id": review_id, "component": "review evidence sink", "budget_ms": design_budget_ms}\n
