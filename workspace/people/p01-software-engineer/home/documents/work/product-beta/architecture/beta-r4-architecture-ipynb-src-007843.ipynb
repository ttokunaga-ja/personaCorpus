# %% [markdown]
# # Beta R4 evidence 007843\nAster Loop株式会社 | BETA-R4 | ADR-B4-083 | 2026-08-17 architecture review | 225 ms design p95 budget | p01-src-007843\nSubject: release-lane telemetry.\n

# %%
source_id = "p01-src-007843"\nreview_id = "ADR-B4-083"\ntarget_ms = 225\nallocation_ms = 151\nassert allocation_ms <= target_ms\n
