# %% [markdown]
# # Beta R4 evidence 007443\nAster Loop株式会社 | BETA-R4 | ADR-B4-081 | 2026-08-17 architecture review | 225 ms design p95 budget | p01-src-007443\nSubject: command decision lineage.\n

# %%
source_id = "p01-src-007443"\nreview_id = "ADR-B4-081"\ntarget_ms = 225\nallocation_ms = 159\nassert allocation_ms <= target_ms\n
