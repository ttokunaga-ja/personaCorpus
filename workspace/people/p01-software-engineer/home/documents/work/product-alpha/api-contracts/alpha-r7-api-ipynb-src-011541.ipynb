# %% [markdown]
# # API-A7-11541 compatibility review\nSynthetic Product Alpha R7 contract evidence.

# %%
contract_id = 'API-A7-11541'\ntarget_p95_ms = 200\nreference_p95_ms = 184\nassert target_p95_ms >= reference_p95_ms\n

# %% [markdown]
# Resource: `decision-records`; operation: `evaluate`; state: `reviewed`.
