# %% [markdown]
# # Product Alpha R7 post-release review REL-A7-20260719-01\nArtifact p01-full-008342; synthetic Aster Loop evidence.\n

# %%
observed_p95_ms = 184\nslo_ceiling_ms = 200\nassert observed_p95_ms <= slo_ceiling_ms\n

# %% [markdown]
# ADR-042 retains the asynchronous release gate on 2026-07-20.\n
