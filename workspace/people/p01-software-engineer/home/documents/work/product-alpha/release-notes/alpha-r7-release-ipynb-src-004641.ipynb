# %% [markdown]
# # Product Alpha R7 release record REL-A7-20260714-83\nSynthetic evidence review for REL-A7-20260714-83.\n

# %%
observed_p95_ms = 184\nslo_ceiling_ms = 200\nassert observed_p95_ms <= slo_ceiling_ms\n

# %% [markdown]
# ADR-042 retains the asynchronous release gate; source p01-src-004641.\n
