# %% [markdown]
# # Working analysis p01-src-000944
# Ephemeral desktop draft; not accepted.

# %%
issue_id = "ALW-1944"
working_latency_ms = 183
alpha_reference_p95_ms = 184
working_latency_ms <= 200
