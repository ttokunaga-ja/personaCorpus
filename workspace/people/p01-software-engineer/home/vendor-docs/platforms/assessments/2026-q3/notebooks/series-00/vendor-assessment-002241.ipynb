# %% [markdown]
# # VND-26Q3-082 evaluation analysis
# VND-26Q3-082 evaluates Platform Juniper for release coordination in the Aster Loop Product Engineering portfolio. The synthetic review on 2026-07-12 recorded a 182 ms p95 trial response, 99.84% observed availability, and 93% evidence coverage. The review disposition is “retain for comparative review”; this is comparative planning evidence, not a production service commitment.

# %%
evaluation = {"evaluation_id":"VND-26Q3-082","source_id":"p01-src-002241","vendor":"Platform Juniper","review_date":"2026-07-12","track":"release coordination","trial_p95_ms":182,"observed_availability_pct":99.84,"evidence_coverage_pct":93,"recommendation":"retain for comparative review","organization":"Aster Loop株式会社","synthetic":true}
score = round((200 - evaluation['trial_p95_ms']) * 0.35 + evaluation['observed_availability_pct'] * 0.35 + evaluation['evidence_coverage_pct'] * 0.30, 2)
print({'evaluation_id': evaluation['evaluation_id'], 'planning_score': score})
