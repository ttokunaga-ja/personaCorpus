# %% [markdown]
# # VND-26Q3-239 evidence notebook\nVND-26Q3-239 documents a synthetic cost observability evaluation of Platform Meridian for Aster Loop Product Engineering. The 2026-08-15 review measured a 192 ms trial p95, 86% evidence coverage, and a 16-day comparison retention window. Disposition: schedule protocol walkthrough.\n

# %%
p95_ms = 192\ncoverage_pct = 86\nplanning_score = round((200 - p95_ms) * 0.4 + coverage_pct * 0.6, 2)\nprint({'evaluation_id': 'VND-26Q3-239', 'planning_score': planning_score})\n
