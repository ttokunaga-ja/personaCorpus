# %% [markdown]
# # Candidate latency analysis (synthetic)\nAster Loop 株式会社 · Product Alpha R7 · 2026-07-13 · ADR-042. **Review required:** this downloaded notebook is not release evidence.

# %%
samples_ms = [91, 127, 158, 176, 181, 184, 184, 203, 228, 244]\ntarget_p95_ms = 184\n

# %%
ordered = sorted(samples_ms)\np95_ms = ordered[8]  # deterministic nearest-rank p95 for ten synthetic samples\nprint(f'synthetic sample count={len(ordered)}')\nprint(f'p95_ms={p95_ms}')\nprint(f'target_margin_ms={target_p95_ms - p95_ms}')
# Out:
# synthetic sample count=10\np95_ms=184\ntarget_margin_ms=0\n

# %% [markdown]
# Result is a saved synthetic output only. Validate sampling, percentile method, and the ADR-042 gate independently before any rollout decision.
