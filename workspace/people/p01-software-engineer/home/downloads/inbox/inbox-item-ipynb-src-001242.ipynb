# %% [markdown]
# # INBOX-001242 incoming analysis\nStatus: unreviewed-inbox; synthetic and unaccepted.\n

# %%
source_id = "p01-src-001242"\nrelease = "BETA-R4"\nobserved_p95_ms = 186\naccepted = False\n
