# %% [markdown]
# # Product Alpha R7 latency
# Aster Loop 株式会社 / 2026-07-13 / p95 184 ms / ADR-042

# %%
samples=[150,160,170,176,179,180,181,182,183,184]
p95=sorted(samples)[int(.95*(len(samples)-1))]
p95
# Out:
# 184
