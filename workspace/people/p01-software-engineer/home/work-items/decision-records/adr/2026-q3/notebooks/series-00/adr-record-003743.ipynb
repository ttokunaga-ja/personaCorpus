# %% [markdown]
# # ADR-162 lifecycle evidence\nSynthetic evaluation for p01-src-003743; Product Alpha R7.\n

# %%
record_id = "p01-src-003743"
adr_id = "ADR-162"
observed_p95_ms = 184
ceiling_ms = 200
assert observed_p95_ms <= ceiling_ms
print({"record_id": record_id, "adr_id": adr_id, "gate_within_ceiling": True})
