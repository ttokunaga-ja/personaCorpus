# %% [markdown]
# # ADR-B4-063 lifecycle evidence\nSynthetic evaluation for p01-src-003843; Product Beta R4.\n

# %%
record_id = "p01-src-003843"
adr_id = "ADR-B4-063"
observed_p95_ms = 184
ceiling_ms = 200
assert observed_p95_ms <= ceiling_ms
print({"record_id": record_id, "adr_id": adr_id, "gate_within_ceiling": True})
