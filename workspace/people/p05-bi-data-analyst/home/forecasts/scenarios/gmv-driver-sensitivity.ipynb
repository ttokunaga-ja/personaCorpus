# %% [markdown]
# # GMV Driver Sensitivity
# Synthetic Mosaic Retail FY26 Q3 scenario analysis. As of 2026-07-13; metric MTR-09.

# %%
gross_actual=86000000
growth=[0,.03,.06,.09]
refund=[.015,.021,.027,.033]
grid=[[round(gross_actual*(1+g+.018)*(1-r)) for g in growth] for r in refund]
print(grid)
# Out:
# [[86234780, 88776080, 91317380, 93858680], [85709492, 88235312, 90761132, 93286952], [85184204, 87694544, 90204884, 92715224], [84658916, 87153776, 89648636, 92143496]]
