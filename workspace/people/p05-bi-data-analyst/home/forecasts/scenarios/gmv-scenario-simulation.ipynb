# %% [markdown]
# # GMV Scenario Simulation
# Synthetic Mosaic Retail FY26 Q3 scenario analysis. As of 2026-07-13; metric MTR-09.

# %%
gross_actual=86000000
scenarios={'base':(.045,.021,.018),'upside':(.092,.018,.025),'downside':(-.038,.028,.010)}
results={k:round(gross_actual*(1+g+p)*(1-r)) for k,(g,r,p) in scenarios.items()}
print(results)
# Out:
# {'base': 89498222, 'upside': 94332884, 'downside': 81251424}
