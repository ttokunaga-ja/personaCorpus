# %% [markdown]
# # Promotion lift exploration
# Directional synthetic cohort comparison; not causal attribution.

# %%
actual_gmv = 84_200_000
plan_gmv = 80_000_000
prior_gmv = 78_600_000
plan_lift_pct = round((actual_gmv / plan_gmv - 1) * 100, 2)
prior_lift_pct = round((actual_gmv / prior_gmv - 1) * 100, 2)
print({'vs_plan_pct': plan_lift_pct})
print({'vs_prior_pct': prior_lift_pct})
# Out:
# {'vs_plan_pct': 5.25}
# {'vs_prior_pct': 7.12}

# %%
assert actual_gmv - plan_gmv == 4_200_000
'Review promotion attribution before taking action.'
# Out:
# 'Review promotion attribution before taking action.'
